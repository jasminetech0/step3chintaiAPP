# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import pandas as pd

# %%
# SUUMOのURL
url = "https://suumo.jp/jj/chintai/ichiran/FR301FC011/?ar=030&bs=040&fw=%E5%8D%83%E4%BB%A3%E7%94%B0%E5%8C%BA"

# %%
# リクエストを送信
response = requests.get(url)

# BeautifulSoupオブジェクトを作成
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# 物件のリストを初期化
properties_list = []

# すべての物件リストアイテムを取得
property_items = soup.find_all('div', class_='property')

# 物件が見つかった場合の処理
for item in property_items:
    property_data = {
        '物件名': item.find('a', class_='js-cassetLinkHref').text if item.find('a', class_='js-cassetLinkHref') else '-',
        'URL': 'https://suumo.jp' + item.find('a', class_='js-cassetLinkHref')['href'] if item.find('a', class_='js-cassetLinkHref') else '-',
        'イメージ画像': item.find('img', class_='js-noContextMenu')['rel'] if item.find('img', class_='js-noContextMenu') else '-',
        '賃料': int(float(item.find('div', class_='detailbox-property-point').text.replace('万円', '')) * 10000) if item.find('div', class_='detailbox-property-point') else '-',
        '管理費': item.find('td', class_='detailbox-property--col1').find_all('div')[1].text.replace('管理費 ', '') if item.find('td', class_='detailbox-property--col1') and len(item.find('td', class_='detailbox-property--col1').find_all('div')) > 1 else '-',
        '間取り': item.find('td', class_='detailbox-property--col3').find_all('div')[0].text if item.find('td', class_='detailbox-property--col3') else '-',
        '専有面積': item.find('td', class_='detailbox-property--col3').find_all('div')[1].text.replace('\n', '').strip() if item.find('td', class_='detailbox-property--col3') else '-',
        '向き': item.select('td.detailbox-property--col3')[0].find_all('div')[2].text if len(item.select('td.detailbox-property--col3')[0].find_all('div')) > 2 else '-' if item.select('td.detailbox-property--col3') else '-',
        '物件種別': item.select('td.detailbox-property--col3')[1].find_all('div')[0].text if len(item.select('td.detailbox-property--col3')) > 1 else '-' if item.select('td.detailbox-property--col3') else '-',
        '築年数': item.select('td.detailbox-property--col3')[1].find_all('div')[1].text if len(item.select('td.detailbox-property--col3')[1].find_all('div')) > 1 else '-' if item.select('td.detailbox-property--col3') else '-',
        '住所': item.select_one('td.detailbox-property-col:not([class*="detailbox-property--"])').text.strip() if item.select_one('td.detailbox-property-col:not([class*="detailbox-property--"])') else '-',
        '最寄り駅と距離': item.select_one('.detailnote-box > div').text.strip() if item.select_one('.detailnote-box > div') else '-',
        '敷金': item.find('td', class_='detailbox-property--col2').find_all('div')[0].contents[-1].strip() if item.find('td', class_='detailbox-property--col2') else '-',
        '礼金': item.find('td', class_='detailbox-property--col2').find_all('div')[1].contents[-1].strip() if item.find('td', class_='detailbox-property--col2') else '-',
        '保証金': item.find('div', class_='detailbox-property-inactive', string=lambda text: '保証金' in text).text.replace('保証金', '').strip() if item.find('div', class_='detailbox-property-inactive', string=lambda text: '保証金' in text) else '-',
        '敷引・償却': item.find('div', class_='detailbox-property-inactive', string=lambda text: '敷引・償却' in text).text.replace('敷引・償却', '').strip() if item.find('div', class_='detailbox-property-inactive', string=lambda text: '敷引・償却' in text) else '-',
        '取り扱い店舗': item.select_one('.detailnote-box .detailnote-box-item div:nth-of-type(1)').text.strip() if item.select_one('.detailnote-box .detailnote-box-item div:nth-of-type(1)') else '-',
        '取り扱い店舗の電話番号': item.find('div', class_='ui-text--bold').text.strip() if item.find('div', class_='ui-text--bold') else '-'
    }

    properties_list.append(property_data)

# データフレームに変換
df = pd.DataFrame(properties_list)

# データフレームを表示
print(df)

# データフレームをCSVファイルに出力
df.to_csv('chiyoda_page1_all_property.csv', index=False, encoding='utf-8-sig')
print("データがCSVファイル 'chiyoda_page1_all_property.csv' に保存されました。")
# Out:
#                  物件名                                        URL  \
# 0        イシカワビレッジ 3階  https://suumo.jp/chintai/bc_100192305263/
# 1         メゾンホワイト 2階  https://suumo.jp/chintai/bc_100371535158/
# 2         鼻高フラットA 1階  https://suumo.jp/chintai/bc_100371535133/
# 3     アシスト城南マンション 5階  https://suumo.jp/chintai/bc_100379476278/
# 4     スプリングフィールドI 1階  https://suumo.jp/chintai/bc_100365391761/
# 5     ソレイユ若葉セブンツー 2階  https://suumo.jp/chintai/bc_100356944625/
# 6       トランビュー沼田A 2階  https://suumo.jp/chintai/bc_100374027144/
# 7           ハイム三田 2階  https://suumo.jp/chintai/bc_100297643799/
# 8      志村坂上 ワンルーム 1階  https://suumo.jp/chintai/bc_100376496541/
# 9       LIFE　BASE 2階  https://suumo.jp/chintai/bc_100371535221/
# 10         シナーラ衣笠 1階  https://suumo.jp/chintai/bc_100371535145/
# 11       ベルヴュー高崎B 1階  https://suumo.jp/chintai/bc_100378635090/
# 12  ワコーレエレガンス行田第2 2階  https://suumo.jp/chintai/bc_100378815468/
# 13            ダリア 1階  https://suumo.jp/chintai/bc_100378815550/
# 14          リコリスB 1階  https://suumo.jp/chintai/bc_100357325490/
# 15          リコリスA 1階  https://suumo.jp/chintai/bc_100341365842/
# 16        湘南平塚コート 3階  https://suumo.jp/chintai/bc_100365391872/
# 17          ハイム三田 2階  https://suumo.jp/chintai/bc_100373805509/
# 18      エスポワール・II 1階  https://suumo.jp/chintai/bc_100378815535/
# 19   シャルマンフジ熊谷壱番館 3階  https://suumo.jp/chintai/bc_100376516621/
# 20        フリーダムＢ棟 1階  https://suumo.jp/chintai/bc_100376516689/
# 21           佐竹ビル 4階  https://suumo.jp/chintai/bc_100361697444/
# 22         モトミハウス 3階  https://suumo.jp/chintai/bc_100136684975/
# 23        メモリーヒルズ 2階  https://suumo.jp/chintai/bc_100381569837/
# 24        ペアパレス朝霞 3階  https://suumo.jp/chintai/bc_100371706179/
# 25          コーポ小山 1階  https://suumo.jp/chintai/bc_100214737721/
# 26     ザ・ファースト西所沢 2階  https://suumo.jp/chintai/bc_100376516671/
# 27        クーノス北坂戸 4階  https://suumo.jp/chintai/bc_100378815557/
# 28           アザレア 2階  https://suumo.jp/chintai/bc_100378815561/
# 29     都立家政 ワンルーム 2階  https://suumo.jp/chintai/bc_100377397150/
#
#                                                イメージ画像     賃料     管理費    間取り  \
# 0   https://img01.suumo.com/front/gazo/fr/bukken/2...  15000   7000円  ワンルーム
# 1   https://img01.suumo.com/front/gazo/fr/bukken/1...  19000   3000円  ワンルーム
# 2   https://img01.suumo.com/front/gazo/fr/bukken/1...  20000   3000円     1K
# 3   https://img01.suumo.com/front/gazo/fr/bukken/2...  22000   3000円  ワンルーム
# 4   https://img01.suumo.com/front/gazo/fr/bukken/7...  22000   3000円     1K
# 5   https://img01.suumo.com/front/gazo/fr/bukken/6...  22000   3000円     1K
# 6   https://img01.suumo.com/front/gazo/fr/bukken/1...  23000   2000円     1K
# 7   https://img01.suumo.com/front/gazo/fr/bukken/7...  25000   3000円  ワンルーム
# 8   https://img01.suumo.com/front/gazo/fr/bukken/5...  25000  23000円  ワンルーム
# 9   https://img01.suumo.com/front/gazo/fr/bukken/2...  26000   3000円  ワンルーム
# 10  https://img01.suumo.com/front/gazo/fr/bukken/1...  26000   3000円  ワンルーム
# 11  https://img01.suumo.com/front/gazo/fr/bukken/0...  27000   3000円     1K
# 12  https://img01.suumo.com/front/gazo/fr/bukken/4...  27000   3000円     1K
# 13  https://img01.suumo.com/front/gazo/fr/bukken/5...  27000   3000円  ワンルーム
# 14  https://img01.suumo.com/front/gazo/fr/bukken/4...  27000   3000円     1K
# 15  https://img01.suumo.com/front/gazo/fr/bukken/8...  27000   3000円     1K
# 16  https://img01.suumo.com/front/gazo/fr/bukken/8...  27000   5000円  ワンルーム
# 17  https://img01.suumo.com/front/gazo/fr/bukken/5...  28000   3000円  ワンルーム
# 18  https://img01.suumo.com/front/gazo/fr/bukken/5...  29000   2000円     1K
# 19  https://img01.suumo.com/front/gazo/fr/bukken/6...  29000   3000円     1K
# 20  https://img01.suumo.com/front/gazo/fr/bukken/6...  29000   3000円     1K
# 21  https://img01.suumo.com/front/gazo/fr/bukken/4...  29000   6000円  ワンルーム
# 22  https://img01.suumo.com/front/gazo/fr/bukken/9...  29800       -    3DK
# 23  https://img01.suumo.com/front/gazo/fr/bukken/8...  30000       -     1K
# 24  https://img01.suumo.com/front/gazo/fr/bukken/1...  30000   1000円  ワンルーム
# 25  https://img01.suumo.com/front/gazo/fr/bukken/7...  30000   2000円  ワンルーム
# 26  https://img01.suumo.com/front/gazo/fr/bukken/6...  30000   2000円     1K
# 27  https://img01.suumo.com/front/gazo/fr/bukken/5...  30000   3000円     1K
# 28  https://img01.suumo.com/front/gazo/fr/bukken/5...  30000   3000円     1K
# 29  https://img01.suumo.com/front/gazo/fr/bukken/1...  30000  17000円  ワンルーム
#
#        専有面積  向き   物件種別   築年数             住所                           最寄り駅と距離  \
# 0      20m2   -  マンション  築32年      茨城県水戸市石川１                    ＪＲ常磐線/赤塚駅 歩29分
# 1    13.5m2   南  マンション  築42年       群馬県高崎市新町                    ＪＲ高崎線/新町駅 歩13分
# 2   25.74m2  南西   アパート  築34年      群馬県高崎市鼻高町                 ＪＲ信越本線/群馬八幡駅 歩30分
# 3      21m2   南  マンション  築37年      茨城県水戸市城南２                    ＪＲ常磐線/水戸駅 歩11分
# 4   20.04m2   南  マンション  築35年     群馬県高崎市下豊岡町                  ＪＲ信越本線/北高崎駅 歩28分
# 5   13.68m2   南   アパート  築37年    埼玉県鶴ヶ島市富士見５                    東武東上線/若葉駅 歩23分
# 6      20m2  南西   アパート  築33年      群馬県沼田市薄根町                     ＪＲ上越線/沼田駅 歩6分
# 7      12m2   西  マンション  築39年  神奈川県川崎市多摩区三田１                      小田急線/生田駅 歩7分
# 8       7m2   -   アパート   築9年     東京都板橋区前野町４                   都営三田線/志村坂上駅 歩7分
# 9    25.4m2   東  マンション  築34年      茨城県水戸市松本町                    ＪＲ常磐線/水戸駅 歩47分
# 10   13.3m2   -   アパート  築37年    神奈川県横須賀市平作２                   ＪＲ横須賀線/衣笠駅 歩12分
# 11  24.33m2   東   アパート  築29年      群馬県高崎市石原町              ＪＲ高崎線/高崎駅 車9分(2.5km)
# 12  17.93m2   -  マンション  築34年     埼玉県行田市門井町３                    ＪＲ高崎線/行田駅 歩19分
# 13     16m2  南西   アパート  築33年     埼玉県東松山市元宿１                    東武東上線/高坂駅 歩10分
# 14   12.6m2   南   アパート  築33年     埼玉県東松山市元宿１                     東武東上線/高坂駅 歩9分
# 15   12.1m2   南   アパート  築33年     埼玉県東松山市元宿１                     東武東上線/高坂駅 歩9分
# 16  17.77m2   東  マンション  築30年      神奈川県平塚市河内     ＪＲ東海道本線/平塚駅 バス20分 (バス停)河内 歩9分
# 17     12m2   東  マンション  築39年  神奈川県川崎市多摩区三田１                      小田急線/生田駅 歩7分
# 18  17.57m2   南   アパート  築18年    栃木県宇都宮市上大曽町  ＪＲ日光線/宇都宮駅 バス14分 (バス停)河内庁舎正門 歩7分
# 19   18.5m2  南東  マンション  築34年      埼玉県熊谷市見晴町                    ＪＲ高崎線/熊谷駅 歩18分
# 20   16.9m2  北東   アパート  築37年    埼玉県鶴ヶ島市富士見５                    東武東上線/若葉駅 歩18分
# 21    3.2m2   -  マンション  築57年      東京都新宿区新宿２                  都営新宿線/新宿三丁目駅 歩5分
# 22  52.89m2   -  マンション  築52年     群馬県桐生市境野町２                    ＪＲ両毛線/桐生駅 歩31分
# 23  17.95m2   南   アパート  築31年     東京都立川市若葉町２      ＪＲ中央線/国立駅 バス9分 (バス停)変電所前 歩2分
# 24  10.75m2   -  マンション  築38年      埼玉県朝霞市栄町４                    東武東上線/朝霞駅 歩16分
# 25     16m2  北西  マンション  築39年       東京都北区岩淵町                東京メトロ南北線/赤羽岩淵駅 歩4分
# 26  15.66m2   西   アパート  築38年     埼玉県所沢市西所沢２                    西武池袋線/西所沢駅 歩8分
# 27  21.51m2   南  マンション  築38年      埼玉県坂戸市芦山町                    東武東上線/北坂戸駅 歩6分
# 28  18.49m2   東   アパート  築36年     埼玉県東松山市元宿２                     東武東上線/高坂駅 歩6分
# 29   8.28m2   南   アパート  築45年      東京都中野区若宮１                   西武新宿線/都立家政駅 歩4分
#
#      敷金   礼金  保証金 敷引・償却                     取り扱い店舗    取り扱い店舗の電話番号
# 0     -    -    -     -             不動産通信社 (株)ユウラク   03-5205-8424
# 1     -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 2     -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 3     -    -    -     -               (株)アシスト・ビジネス   03-5980-9395
# 4     -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 5     -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 6     -    -    -     -               (株)アシスト・ビジネス   03-5980-9395
# 7     -    -    -     -        アパルトマンエージェント(株)東京支社   03-5822-1087
# 8     -    -    -     -                   (株)東京めぞん   03-5280-7180
# 9     -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 10    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 11    -    -    -     -               (株)アシスト・ビジネス   03-5980-9395
# 12    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 13    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 14    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 15    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 16    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 17    -    -    -     -        アパルトマンエージェント(株)東京支社   03-5822-1087
# 18    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 19    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 20    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 21    -    -  3万円   3万円                (株)オッズ・スペース   03-5846-9399
# 22    -    -    -     -             不動産通信社 (株)ユウラク   03-5205-8424
# 23    -    -    -     -              (有)東京学生センター本社   03-3221-1239
# 24    -    -    -     -                  日本中央管理(株)  050-3503-2308
# 25  3万円  3万円    -     -           お茶の水賃貸センター (株)総伸   03-3292-4461
# 26    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 27    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 28    -    -    -     -  武蔵コミュニティー(株)東京本社賃貸のi live   03-6206-3371
# 29    -    -    -     -         ファミーユホーム(株)ピーアイホーム   03-6910-0383
# データがCSVファイル 'chiyoda_page1_all_property.csv' に保存されました。

# %%
import os

# 現在の作業ディレクトリを取得
current_directory = os.getcwd()
print("現在の作業ディレクトリ:", current_directory)

# 物件のリストを初期化
properties_list = []

# すべての物件リストアイテムを取得
property_items = soup.find_all('div', class_='property')

for item in property_items:
    property_data = {
        '物件名': item.find('a', class_='js-cassetLinkHref').text if item.find('a', class_='js-cassetLinkHref') else '-',
        'URL': 'https://suumo.jp' + item.find('a', class_='js-cassetLinkHref')['href'] if item.find('a', class_='js-cassetLinkHref') else '-',
        'イメージ画像': item.find('img', class_='js-noContextMenu')['rel'] if item.find('img', class_='js-noContextMenu') else '-',
        '賃料': int(float(item.find('div', class_='detailbox-property-point').text.replace('万円', '')) * 10000) if item.find('div', class_='detailbox-property-point') else '-',
        '管理費': item.find('td', class_='detailbox-property--col1').find_all('div')[1].text.replace('管理費 ', '') if item.find('td', class_='detailbox-property--col1') and len(item.find('td', class_='detailbox-property--col1').find_all('div')) > 1 else '-',
        '間取り': item.find('td', class_='detailbox-property--col3').find_all('div')[0].text if item.find('td', class_='detailbox-property--col3') else '-',
        '専有面積': item.find('td', class_='detailbox-property--col3').find_all('div')[1].text.replace('\n', '').strip() if item.find('td', class_='detailbox-property--col3') else '-',
        '向き': item.select('td.detailbox-property--col3')[0].find_all('div')[2].text if len(item.select('td.detailbox-property--col3')[0].find_all('div')) > 2 else '-' if item.select('td.detailbox-property--col3') else '-',
        '物件種別': item.select('td.detailbox-property--col3')[1].find_all('div')[0].text if len(item.select('td.detailbox-property--col3')) > 1 else '-' if item.select('td.detailbox-property--col3') else '-',
        '築年数': item.select('td.detailbox-property--col3')[1].find_all('div')[1].text if len(item.select('td.detailbox-property--col3')[1].find_all('div')) > 1 else '-' if item.select('td.detailbox-property--col3') else '-',
        '住所': item.select_one('td.detailbox-property-col:not([class*="detailbox-property--"])').text.strip() if item.select_one('td.detailbox-property-col:not([class*="detailbox-property--"])') else '-',
        '最寄り駅と距離': item.select_one('.detailnote-box > div').text.strip() if item.select_one('.detailnote-box > div') else '-',
        '敷金': item.find('td', class_='detailbox-property--col2').find_all('div')[0].contents[-1].strip() if item.find('td', class_='detailbox-property--col2') else '-',
        '礼金': item.find('td', class_='detailbox-property--col2').find_all('div')[1].contents[-1].strip() if item.find('td', class_='detailbox-property--col2') else '-',
        '保証金': item.find('div', class_='detailbox-property-inactive', string=lambda text: '保証金' in text).text.replace('保証金', '').strip() if item.find('div', class_='detailbox-property-inactive', string=lambda text: '保証金' in text) else '-',
        '敷引・償却': item.find('div', class_='detailbox-property-inactive', string=lambda text: '敷引・償却' in text).text.replace('敷引・償却', '').strip() if item.find('div', class_='detailbox-property-inactive', string=lambda text: '敷引・償却' in text) else '-',
        '取り扱い店舗': item.select_one('.detailnote-box .detailnote-box-item div:nth-of-type(1)').text.strip() if item.select_one('.detailnote-box .detailnote-box-item div:nth-of-type(1)') else '-',
        '取り扱い店舗の電話番号': item.find('div', class_='ui-text--bold').text.strip() if item.find('div', class_='ui-text--bold') else '-'
    }

    properties_list.append(property_data)

# データフレームに変換
df = pd.DataFrame(properties_list)

# データフレームをCSVファイルに出力
df.to_csv('chiyoda_page1_all_property.csv', index=False, encoding='utf-8-sig')
print("データがCSVファイル 'chiyoda_page1_all_property.csv' に保存されました。")

# SQLiteデータベースのパスを設定（現在の作業ディレクトリに保存）
database_path = os.path.join(current_directory, 'chiyoda_page1_all_property.sqlite')

# SQLiteデータベースに接続（なければ新規作成）
conn = sqlite3.connect('chiyoda_page1_all_property.sqlite')
c = conn.cursor()

# テーブルを作成
c.execute('''
CREATE TABLE IF NOT EXISTS properties (
    物件名 TEXT,
    URL TEXT,
    イメージ画像 TEXT,
    賃料 INTEGER,
    管理費 TEXT,
    間取り TEXT,
    専有面積 TEXT,
    向き TEXT,
    物件種別 TEXT,
    築年数 TEXT,
    住所 TEXT,
    最寄り駅と距離 TEXT,
    敷金 TEXT,
    礼金 TEXT,
    保証金 TEXT,
    敷引・償却 TEXT,
    取り扱い店舗 TEXT,
    取り扱い店舗の電話番号 TEXT
)
''')

# データフレームの内容をSQLiteに挿入
df.to_sql('properties', conn, if_exists='replace', index=False)

# コネクションを閉じる
conn.close()
print(f"データがSQLiteデータベース '{database_path}' に保存されました。")
# Out:
# 現在の作業ディレクトリ: c:\Users\jiebing\Desktop\ChintaiAPP\make_db
# データがCSVファイル 'chiyoda_page1_all_property.csv' に保存されました。
# データがSQLiteデータベース 'c:\Users\jiebing\Desktop\ChintaiAPP\make_db\chiyoda_page1_all_property.sqlite' に保存されました。
